# %%
import numpy as np

# %%
n = 20
d = 20

# %%
x = np.random.randn(n, d)
y = np.random.randn(n, 1)
lbd = 0.1
tmp = np.linalg.inv(x.T @ x + lbd * np.eye(d)) 
theta = tmp @ x.T @ y
H_l_inv = 0.5 * tmp

# %%
H_l_list = [] 
for i in range(n):
    cur_value = 2 * (x[i] @ x[i].T) + 2 * lbd / n * np.eye(d)
    H_l_list.append(cur_value)

# %%
g_list = []
for j in range(n):
    cur_value = 2 * (x[j] @ theta - y[j]) * x[j] + 2 * lbd / n * theta.squeeze()
    g_list.append(cur_value)

# %%
p_1 = p_2 = 2 * (x.T @ x @ theta - x.T @ y)

# %%
h_1 = h_2 = x.T @ x

# %%
pm_list = []
for j in range(n):
    cur_value = (2 * (x[j] @ theta - y[j]) * x[j]).reshape(d, 1)
    pm_list.append(cur_value)

# %%
T = np.zeros((n, n))

for i in range(n):
    for j in range(n):
        if i == j: continue
        term1 = - g_list[j] @ (H_l_inv @ H_l_list[i] @ H_l_inv @ p_1)
        term2 = - g_list[i] @ (H_l_inv @ H_l_list[j] @ H_l_inv @ p_1)
        term3 = 0
        # term3 = - g_list[i] @ (H_l_inv @ pm_list[j])
        term4 = g_list[i] @ H_l_inv @ h_1 @ H_l_inv @ g_list[j]
        T[i][j] = term1 + term2 + term3 + term4
# Out:
# /tmp/ipykernel_3383685/478985606.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   T[i][j] = term1 + term2 + term3 + term4

# %%
T
# Out:
# array([[ 0.00000000e+00, -5.11068149e+00, -4.63738672e+00,
#         -1.63820571e+01, -1.11711908e+01,  6.95802382e+00,
#         -9.55904115e-01, -9.83686784e+00, -8.69715276e+00,
#          2.14863789e+00, -4.50152537e+00, -5.39802921e+00,
#         -2.14068874e+01, -8.48368940e+00, -1.38121136e+01,
#         -3.78240416e+00, -1.13606466e+01, -8.47792446e+00,
#         -5.28543688e+00, -6.87626393e+00],
#        [-5.11068149e+00,  0.00000000e+00,  1.67088930e+01,
#         -1.03238287e+00,  1.01742209e+01,  2.43595124e+01,
#          1.71704997e+01,  1.23789669e+01,  2.32141750e+00,
#          1.28985436e+01,  7.90804971e+00,  9.54223351e+00,
#         -8.04632286e+00,  3.33011402e+00, -1.24128632e+01,
#          8.63902455e+00,  9.42004237e-01, -5.58164449e-01,
#          5.68559217e+00,  1.06992139e+01],
#        [-4.63738672e+00,  1.67088930e+01,  0.00000000e+00,
#         -1.36467222e+00,  7.98153988e+00,  2.01667252e+01,
# ...
